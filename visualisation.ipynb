# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test_arr = np.load('/home/ning/data/NC2C_OxAAA_paired_160_160_128/test/train/images/NM007_TP-3_C.npy')

# %%
test_arr = np.clip(test_arr, 1000, 1256)

# %%
print(test_arr.max())
print(test_arr.min())
# Out:
# 2309.8347
# -283.37213

# %%
print(test_arr.shape)
plt.imshow(test_arr[...,64],cmap='gray')
plt.show()
# Out:
# (160, 160, 128)
